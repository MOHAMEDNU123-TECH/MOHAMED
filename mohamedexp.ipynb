# %% [markdown]
# <a href="https://colab.research.google.com/github/MOHAMEDNU123-TECH/MOHAMED/blob/main/mohamedexp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-10,10,0.001)
y = np.exp(x)
plt.plot(x,y)
plt.title("Exponential curve")
plt.show()
